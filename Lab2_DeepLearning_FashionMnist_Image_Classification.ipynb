# %%
#!pip install tensorflow

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1-Create or download dataset

# %%
fashion_mnist=tf.keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()
print(train_images.shape)
# Out:
# (60000, 28, 28)

# %%
class_names=[
    'T-shirt/top',
    'Pantalon',
    'Pullover',
    'Robe',
    'Manteau',
    'Sandale',
    'Chemise',
    'Sneaker',
    'Sac',
    'Bottine'
]

# %%
plt.figure()
plt.imshow(train_images[1],cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()
print(train_labels[1])
# Out:
# 0

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # 2-Create the model

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='sigmoid'),
    tf.keras.layers.Dense(10,activation='softmax')
])

# %% [markdown]
# # Configure the model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # 3-Train the model

# %%
model.fit(train_images,train_labels,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5397 - accuracy: 0.8157
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3913 - accuracy: 0.8600
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3538 - accuracy: 0.8713
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3285 - accuracy: 0.8809
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3108 - accuracy: 0.8863
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2957 - accuracy: 0.8924
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2825 - accuracy: 0.8959
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2726 - accuracy: 0.9008
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2610 - accuracy: 0.9042
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2521 - accuracy: 0.9060

# %% [markdown]
# # 4-Test the model

# %%
test_loss,test_acc=model.evaluate(test_images,test_labels,verbose=2)
print('\nTest accuracy : ',test_acc*100,'%')
# Out:
# 313/313 - 0s - loss: 0.3303 - accuracy: 0.8809 - 424ms/epoch - 1ms/step
#
# Test accuracy :  88.09000253677368 %
